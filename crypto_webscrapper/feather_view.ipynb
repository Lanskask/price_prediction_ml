# %% [markdown]
# # View first 10 rows of bitcoin_news_final_dataset_hourly.feather

# %%
import os
import pandas as pd

# %%
feather_path = 'bitcoin_news_final_dataset_hourly.feather'

if not os.path.exists(feather_path):
    raise FileNotFoundError(f'File not found: {feather_path}')

df = pd.read_feather(feather_path)
df.head(10)
# Out:
#                  date title description content   url source sentiment  \
# 0 2021-11-01 00:00:00  None        None    None  None   None      None
# 1 2021-11-01 01:00:00  None        None    None  None   None      None
# 2 2021-11-01 02:00:00  None        None    None  None   None      None
# 3 2021-11-01 03:00:00  None        None    None  None   None      None
# 4 2021-11-01 04:00:00  None        None    None  None   None      None
# 5 2021-11-01 05:00:00  None        None    None  None   None      None
# 6 2021-11-01 06:00:00  None        None    None  None   None      None
# 7 2021-11-01 07:00:00  None        None    None  None   None      None
# 8 2021-11-01 08:00:00  None        None    None  None   None      None
# 9 2021-11-01 09:00:00  None        None    None  None   None      None
#
#    sentiment_positive  sentiment_neutral  sentiment_negative  ...  low_price  \
# 0                 NaN                NaN                 NaN  ...        NaN
# ...
